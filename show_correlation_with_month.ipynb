# %%
from auto_run import main_process
from draw_all_colrelation_depart import depart_sn_glb
from draw_all_colrelation_depart import depart_ml_lat_month

# %%
start_key = 'duration'
if start_key == 'wet30':
    percentile_key = 'lsprf'
else:
    percentile_key = start_key
data_set = ['spring', 'summer', 'autumn', 'winter']

# %%
# for ds in data_set:
#     main_process(f'wetday_vt_{start_key}', percentile_name=f'{percentile_key}_percentile', renew='001', data_set=ds)

# %%
data_set_cor = ['winter', 'spring', 'summer', 'autumn', 'wet']
depart_sn_glb(data_set_cor)

# %%
depart_ml_lat_month(data_set_cor)
